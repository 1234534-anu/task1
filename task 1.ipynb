# %%
import pandas as pd
import numpy as np
from scipy import stats
df = pd.read_csv('heart Attack.csv')
print(df.head)
numerical_columns = df.select_dtypes(include=[np.number])
for column in numerical_columns.columns:
    print(f"Column: {column}")
    mean_value = numerical_columns[column].mean()
    median_value = numerical_columns[column].median()
    mode_value = numerical_columns[column].mode().values  # mode() returns a Series

    print(f"Mean: {mean_value}")
    print(f"Median: {median_value}")
    print(f"Mode: {mode_value}")
    print("-" * 30)
# Out:
# <bound method NDFrame.head of       age  gender  impluse  pressurehight  pressurelow  glucose    kcm  \
# 0      64       1       66            160           83    160.0   1.80
# 1      21       1       94             98           46    296.0   6.75
# 2      55       1       64            160           77    270.0   1.99
# 3      64       1       70            120           55    270.0  13.87
# 4      55       1       64            112           65    300.0   1.08
# ...   ...     ...      ...            ...          ...      ...    ...
# 1314   44       1       94            122           67    204.0   1.63
# 1315   66       1       84            125           55    149.0   1.33
# 1316   45       1       85            168          104     96.0   1.24
# 1317   54       1       58            117           68    443.0   5.80
# 1318   51       1       94            157           79    134.0  50.89
#
#       troponin     class
# 0        0.012  negative
# 1        1.060  positive
# 2        0.003  negative
# 3        0.122  positive
# 4        0.003  negative
# ...        ...       ...
# 1314     0.006  negative
# 1315     0.172  positive
# 1316     4.250  positive
# 1317     0.359  positive
# 1318     1.770  positive
#
# [1319 rows x 9 columns]>
# Column: age
# Mean: 56.191811978771796
# Median: 58.0
# Mode: [60]
# ------------------------------
# Column: gender
# Mean: 0.6595905989385898
# Median: 1.0
# Mode: [1]
# ------------------------------
# Column: impluse
# Mean: 78.3366186504928
# Median: 74.0
# Mode: [60]
# ------------------------------
# Column: pressurehight
# Mean: 127.17058377558757
# Median: 124.0
# Mode: [150]
# ------------------------------
# Column: pressurelow
# Mean: 72.26914329037149
# Median: 72.0
# Mode: [75]
# ------------------------------
# Column: glucose
# Mean: 146.63434420015165
# Median: 116.0
# Mode: [100.]
# ------------------------------
# Column: kcm
# Mean: 15.27430553449583
# Median: 2.85
# Mode: [300.]
# ------------------------------
# Column: troponin
# Mean: 0.3609423805913571
# Median: 0.014
# Mode: [0.003]
# ------------------------------
